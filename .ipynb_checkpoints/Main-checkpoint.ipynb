# %% [markdown]
# # Gray-Scott PDE equations
# This notebook shows how to use the function in this git repository to numerically solve the PDE, generate data, run tests and perform inference.

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('python_files/')
from Pde_solver import Solver
from Inference import Inference

# %% [markdown]
# ## Solve PDE and generate data
# The following lines call the `Solver` class to solve the Gray-Scott equations. It uses a square grid with `n_grid` x `n_grid` points, and periodic boundary conditions in both x and y directions. For generating data we recommend `n_grid = 256`, and for inference `n_grid=64`.
#
# #### Time points

# %%
## Initiate PDE solver class 
solv = Solver(n_save_frames=800, n_time_points=8000, model='gray-scott', n_grid=64)

# %%
## Set F & k parameters and solve
## spots: F=0.035, k=0.065
## maze-like: F=0.035, k=0.06

tmp = solv.solve(parameters=[0.035, 0.060], verbose=True, til_convergence=True)  # parameters = [F, k]
# Out:
#   2%|▏         | 195/8000 [00:00<00:04, 1949.61it/s]
# Solving gray-scott model in 8000 time steps.
#  42%|████▏     | 3394/8000 [00:01<00:02, 2073.74it/s]
# Convergence reached after 3461/8000 time points

# %%
## Plot result
plt.imshow(solv.u_mat[:, :])
plt.colorbar()

# %%
plt.plot(solv.convergence)
plt.yscale('log')

# %%
## Or use plotting function from class
solv.plot2d()

# %%
## Save animation to disk
plt.rcParams['figure.figsize'] = (6, 6)
solv.animation()

# %%
len(solv.save_times)
solv.save_times
solv.save_u_mat.reshape(solv.n_save_frames, solv.n_x * solv.n_y).shape
# Out:
# (20, 65536)

# %%
## Initiate inference class:
inference = Inference(solv, solv.save_times, solv.save_u_mat.reshape(solv.n_save_frames, solv.n_x * solv.n_y))
# problem = pints.MultiOutputProblem(solv, solv.save_times, solv.save_u_mat.reshape(solv.n_save_frames, solv.n_x * solv.n_y))

# %%
inference.optimise()
# Out:
# Minimising error measure
# Using Seperable Natural Evolution Strategy (SNES)
# Running in sequential mode.
# Population size: 6
# Iter. Eval. Best      Time m:s
# 0     6      12296.21   0:06.7
# 1     12     12296.21   0:12.4
# 2     18     12296.21   0:16.8
# 3     24     12296.21   0:21.5
# 20    126    12296.21   1:47.6
# 40    246    12296.21   3:18.7
# 60    366    12296.21   4:51.7
# 80    486    12296.21   6:21.8
# 100   606    12296.21   7:55.2
# 120   726    12296.21   9:26.7
# 140   846    12296.21  10:54.2
# 160   966    12296.21  12:23.1
#
# ----------------------------------------
# Unexpected termination.
# Current best score: 12296.210907572162
# Current best position:
#  2.38206826724623108e-02
#  4.21184742298961912e-01
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-6-1543638ae6d8> in <module>
# ----> 1 inference.optimise()
#
# ~/Google Drive/repos/Gray-Scott-PDE/python_files/Inference.py in optimise(self)
#       9         boundaries = pints.RectangularBoundaries([0.01, 0.01], [1.0, 1.0])
#      10         x0 = [0.05, 0.05]
# ---> 11         found_parameters, found_value = pints.optimise(score, x0, boundaries=boundaries, method=pints.SNES)
#      12         print(found_parameters)
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/pints/_optimisers/__init__.py in optimise(function, x0, sigma0, boundaries, method)
#     778     """
#     779     return OptimisationController(
# --> 780         function, x0, sigma0, boundaries, method).run()
#     781
#     782
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/pints/_optimisers/__init__.py in run(self)
#     496
#     497                 # Calculate scores
# --> 498                 fs = evaluator.evaluate(xs)
#     499
#     500                 # Perform iteration
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/pints/_evaluation.py in evaluate(self, positions)
#     105                 'The argument `positions` must be a sequence of input values'
#     106                 ' to the evaluator\'s function.')
# --> 107         return self._evaluate(positions)
#     108
#     109     def _evaluate(self, positions):
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/pints/_evaluation.py in _evaluate(self, positions)
#     397         scores = [0] * len(positions)
#     398         for k, x in enumerate(positions):
# --> 399             scores[k] = self._function(x, *self._args)
#     400         return scores
#     401
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/pints/_error_measures.py in __call__(self, x)
#     298
#     299     def __call__(self, x):
# --> 300         return np.sum((np.sum(((self._problem.evaluate(x) - self._values)**2),
#     301                               axis=0) * self._weights),
#     302                       axis=0)
#
# ~/.conda/envs/py37/lib/python3.7/site-packages/pints/_core.py in evaluate(self, parameters)
#     263         The returned data is a NumPy array with shape ``(n_times, n_outputs)``.
#     264         """
# --> 265         y = np.asarray(self._model.simulate(parameters, self._times))
#     266         return y.reshape(self._n_times, self._n_outputs)
#     267
#
# ~/Google Drive/repos/Gray-Scott-PDE/python_files/Pde_solver.py in simulate(self, parameters, times)
#     257     def simulate(self, parameters, times):
#     258         """Wraps the solve function inside simulate to be compatible with pints"""
# --> 259         value = self.solve(parameters)
#     260         return value
#
# ~/Google Drive/repos/Gray-Scott-PDE/python_files/Pde_solver.py in solve(self, parameters, verbose)
#     193         elif not verbose:  # do not show progress bar
#     194             for i_tau in range(self.n_times):
# --> 195                 forward_diff(i_t=i_tau)
#     196
#     197         self.save_u_mat[-1, :, :] = self.u_mat.copy()
#
# ~/Google Drive/repos/Gray-Scott-PDE/python_files/Pde_solver.py in forward_diff(i_t)
#     186             old_u = self.u_mat.copy()
#     187             old_v = self.v_mat.copy()
# --> 188             self.u_mat, self.v_mat = self.update_uv(old_u_mat=old_u, old_v_mat=old_v)  # do update
#     189
#     190         if verbose:  # show progress bar
#
# ~/Google Drive/repos/Gray-Scott-PDE/python_files/Pde_solver.py in update_uv(self, old_u_mat, old_v_mat)
#     132
#     133         ## Perform diffusion step:
# --> 134         new_u_mat += self.dt * self.diffusion_update(old_u=old_u_mat, diff_coef=self.eps_1)
#     135         new_v_mat += self.dt * self.diffusion_update(old_u=old_v_mat, diff_coef=self.eps_2)
#     136
#
# ~/Google Drive/repos/Gray-Scott-PDE/python_files/Pde_solver.py in diffusion_update(self, old_u, diff_coef)
#     107                             + ((np.roll(old_u, shift=1, axis=1)
#     108                             + np.roll(old_u, shift=-1, axis=1)
# --> 109                             - 2 * old_u) / (self.dy ** 2)))
#     110         return diff
#     111
#
# KeyboardInterrupt:
