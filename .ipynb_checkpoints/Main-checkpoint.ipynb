# %% [markdown]
# # Gray-Scott PDE equations
# This notebook shows how to use the function in this git repository to numerically solve the PDE, generate data, run tests and perform inference.

# %%
import matplotlib.pyplot as plt
import numpy as np
import sys
sys.path.append('python_files/')
sys.path.append('tests/')
from Pde_solver import Solver
from Inference import Inference
from test_solver import convergence_test, diffusion_test
from test_inverseproblem import test_find_parameter

# %% [markdown]
# # Testing
# The cell below tests the functionality of 3 different aspects of this project.
# `diffusion_test()` uses the pde solver to solve the heat equation (which only contains the diffusion term). This validates that the central difference approximation of the laplacian is correct and that the periodic boundary conditions function correctly, by assessing if the energy of the system is conserved.
# `convergence_test()` checks if the convergence criterion works, by looking at a model which is known to converge early.
# `test_find_parameter()` runs our `Inference` class on an exponential growth model, to check if the parameters are correctly inferred.

# %%
assert diffusion_test() is True  # assert if diffusion approximation and boundary conditions work
assert convergence_test() is True  # assert if convergence mechanism works 
assert test_find_parameter() is True  # assert if inference works
# Out:
# Minimising error measure
# Using Seperable Natural Evolution Strategy (SNES)
# Running in sequential mode.
# Population size: 6
# Iter. Eval. Best      Time m:s
# 0     6      29.00531   0:00.0
# 1     12     5.683469   0:00.0
# 2     18     5.683469   0:00.0
# 3     24     5.683469   0:00.0
# 20    126    2.179016   0:00.0
# 40    246    2.179016   0:00.0
# 60    366    2.113575   0:00.1
# 80    486    2.096334   0:00.1
# 100   606    2.095374   0:00.1
# 120   726    2.095194   0:00.1
# 140   846    2.095173   0:00.2
# 160   966    2.095173   0:00.2
# 180   1086   2.095173   0:00.2
# 200   1206   2.095173   0:00.2
# 220   1326   2.095173   0:00.2
# 240   1446   2.095173   0:00.3
# 260   1566   2.095173   0:00.3
# 280   1686   2.095173   0:00.3
# 300   1806   2.095173   0:00.3
# 320   1926   2.095173   0:00.3
# 340   2046   2.095173   0:00.3
# 360   2166   2.095173   0:00.4
# 377   2262   2.095173   0:00.4
# Halting: No significant change for 200 iterations.

# %% [markdown]
# ## Solve PDE and generate data
# The following lines call the `Solver` class to solve the Gray-Scott equations.
#
# #### Spatial grid:
# The solver uses a square grid with `n_grid` x `n_grid` points, and periodic boundary conditions in both x and y directions. For generating data we recommend `n_grid = 256`, and for inference `n_grid=32`.
#
# #### Time points:
# You can set the number of time points to use in `Solver`. Additionally, the `solve()` function can be called with `til_convergence=True` to abort solving once the stopping criterion has been reached (if the summed relative change < `rel_tol`).

# %% [markdown]
# ## Plot results:
# You can either plots results in custom format, by calling `Solver.u_mat` for the latest result or `Solver.save_u_mat[time_frame, :, :]` for intermediate results at `time_frame` (taken at regular intervals, as defined by `n_save_frames`). Similarly one can plot the `v` matrices.
# Alternatively, you can use the plotting functions of `Solver`:
#    - `Solver.plot2d()` to plot the the `u` and `v` matrices.
#    - `Solver.plot_convergence()` to plot the convergence of the PDE
#    - `Solver.animation()` to create a gif animation of all saved intermediate results. This is saved to disk (in the current directory).

# %%
## Set F & k parameters and solve and plot
## spots: F=0.035, k=0.065
F = 0.035
k = 0.065

## Initiate PDE solver class 
SolvSpots = Solver(n_save_frames=100, n_time_points=8000, model='gray-scott', n_grid=256, fix_seed=True)
tmp = SolvSpots.solve(parameters=[F, k], verbose=True, til_convergence=True, init=True)  # parameters = [F, k]
SolvSpots.plot2d()
# Out:
#   0%|          | 27/8000 [00:00<00:30, 265.14it/s]
# Solving gray-scott model in 8000 time steps.
# 100%|██████████| 8000/8000 [00:27<00:00, 293.26it/s]

# %%
## Set F & k parameters and solve and plot
## maze-like: F=0.035, k=0.06
F = 0.035
k = 0.06
SolvMaze = Solver(n_save_frames=100, n_time_points=8000, model='gray-scott', n_grid=256, fix_seed=True)
tmp = SolvMaze.solve(parameters=[F, k], verbose=True, til_convergence=True, init=True)  # parameters = [F, k]
SolvMaze.plot2d()
# Out:
#   0%|          | 26/8000 [00:00<00:30, 258.54it/s]
# Solving gray-scott model in 8000 time steps.
# 100%|██████████| 8000/8000 [00:25<00:00, 309.66it/s]

# %%
## Set F & k parameters and solve and plot
## maze-like: F=0.035, k=0.06
F = 0.05
k = 0.065

solv_stripes = Solver(n_save_frames=100, n_time_points=8000, model='gray-scott', n_grid=256, fix_seed=True)
tmp = solv_stripes.solve(parameters=[F, k], verbose=True, til_convergence=True, init=True)  # parameters = [F, k]
solv_stripes.plot2d()
# Out:
#   0%|          | 24/8000 [00:00<00:34, 234.27it/s]
# Solving gray-scott model in 8000 time steps.
# 100%|██████████| 8000/8000 [00:26<00:00, 301.56it/s]

# %%
## Set F & k parameters and solve and plot
## maze-like: F=0.035, k=0.06
F = 0.035
k = 0.06

SolvConv = Solver(n_save_frames=100, n_time_points=8000, model='gray-scott', n_grid=64, fix_seed=True)
tmp = SolvConv.solve(parameters=[F, k], verbose=True, til_convergence=True, init=True)  # parameters = [F, k]
SolvConv.plot2d()
plt.show()
SolvConv.plot_convergence()
# Out:
#   3%|▎         | 211/8000 [00:00<00:03, 2108.35it/s]
# Solving gray-scott model in 8000 time steps.
#  47%|████▋     | 3727/8000 [00:01<00:01, 2195.00it/s]
# Convergence reached after 3886/8000 time points

# %%
## Save animation to disk (the gif can be viewed there)
plt.rcParams['figure.figsize'] = (6, 6)
SolvConv.animation()
plt.show()

# %% [markdown]
# ## Inference
# Perform inference using `pints`. The `Inference` class is tested at the top of this notebook and functions correctly. However it has proven to be very difficult to infer the `F` and `k` parameters from the Gray-Scott equations. The code below runs the inference, but it has to run for a very long time to get near to the true solution.
# One can interrupt the the process and assess the preliminary parameter estimates.

# %%
## Initiate inference class:
inference = Inference(solv, solv.save_times, solv.save_u_mat.reshape(solv.n_save_frames, solv.n_x * solv.n_y))
# problem = pints.MultiOutputProblem(solv, solv.save_times, solv.save_u_mat.reshape(solv.n_save_frames, solv.n_x * solv.n_y))

# %%
inference.optimise()
# Out:
# Minimising error measure
# Using Seperable Natural Evolution Strategy (SNES)
# Running in sequential mode.
# Population size: 6
# Iter. Eval. Best      Time m:s
# 0     6      977350.3   0:09.1
# python_files/Pde_solver.py:198: RuntimeWarning: invalid value encountered in double_scalars
#   + (np.sum(np.abs(self.v_mat - old_v)) / np.sum(np.abs(old_v))))
# 1     12     977350.3   0:17.4
# 2     18     977350.3   0:25.4
# 3     24     977350.3   0:33.7
# 20    126    977350.3   3:01.0
#
# ----------------------------------------
# Unexpected termination.
# Current best score: 977350.3002742336
# Current best position:
#  2.13285346252927444e-01
#  1.26575948337970923e-01
# ----------------------------------------
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-1543638ae6d8> in <module>
# ----> 1 inference.optimise()
#
# ...
